# %%
import pandas as pd
import numpy as np
from lifelines import CoxPHFitter

# %%
# Load the CSV
df = pd.read_csv("../data/Telco_Customer_Churn_feature_engineered_v1.csv")

# Quick preview
df.head()
# Out:
#    customerID  IsSeniorCitizen  tenure  MonthlyCharges  TotalCharges Churn  \
# 0  7590-VHVEG                0       1           29.85         29.85    No
# 1  5575-GNVDE                0      34           56.95       1889.50    No
# 2  3668-QPYBK                0       2           53.85        108.15   Yes
# 3  7795-CFOCW                0      45           42.30       1840.75    No
# 4  9237-HQITU                0       2           70.70        151.65   Yes
#
#    HasPartnerOrDependents  ExpectedTotalCharges  BillingDiffPct  Churn_num  \
# 0                       1                 29.85        0.000000          0
# 1                       0               1936.30       -0.024170          0
# 2                       0                107.70        0.004178          1
# 3                       0               1903.50       -0.032965          0
# 4                       0                141.40        0.072484          1
#
# ...

# %%
survival_df = df[['tenure', 'Churn_num', 'MonthlyCharges', 'value_segment_Mid', 'value_segment_High', 'value_segment_VIP']]

cph = CoxPHFitter()
cph.fit(survival_df, duration_col='tenure', event_col='Churn_num')
cph.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 7043 total observations, 5174 right-censored observations>
#              duration col = 'tenure'
#                 event col = 'Churn_num'
#       baseline estimation = breslow
#    number of observations = 7043
# number of events observed = 1869
#    partial log-likelihood = -15503.68
#          time fit was run = 2025-07-20 15:50:39 UTC
#
# ---
#                     coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# covariate
# MonthlyCharges     -0.02      0.98      0.00           -0.03           -0.02                0.97                0.98
# value_segment_Mid   1.59      4.91      0.14            1.32            1.86                3.74                6.44
# value_segment_High  2.50     12.17      0.21            2.08            2.91                8.04               18.41
# value_segment_VIP   2.53     12.61      0.28            1.99            3.08                7.33               21.69
#
# ...
